# %% [raw]
# Program 1:
# write a program to take an integer input from the user and print it.
# input:10
# output:you entered integer:10

# %%
num  = int(input("you entered integer: "))
# Out:
# you entered integer:  10

# %% [raw]
# Program 2:
# write a program to take an string input from the user and print it.
# input:core2web
# output: you entered string:core2web

# %%
name = input("you entered string : ")
# Out:
# you entered string :  core2web

# %% [raw]
# Program 3:
# write a program to take an float input from the user and print it.
# input:12.5
# output: you entered float:12.5

# %%
num1 = float(input("you entered float : "))
# Out:
# you entered float :  12.5

# %% [raw]
# Program 4:
# write a program to take two integer input from the user and print their sum.
# input: 5 10
# output: sum of 5 and 10 is 15

# %%
num2 = int(input("enter num2: "))
num3 = int(input("enter num3: "))
sum = num2 + num3
print("sum of 5 and 10 is ",sum)
# Out:
# enter num2:  5
# enter num3:  10
# sum of 5 and 10 is  15

# %% [raw]
# Program 5:
# write a program to take a user's name(string) and age(integer) as input  and print it.
# input:
#      name : core2web
#      age : 8
# output:
#      name : core2web
#      age : 8

# %%
name = input("enter name : ")
age = int(input("enter age : "))
# Out:
# enter name :  core2web
# enter age :  8

# %% [raw]
# Program 6:
# write a program to take three float numbers from the user  and print their average.
# input: 4.5 , 3.5 , 2.0
# output:Average of numbers is 3.33

# %%
num1 = float(input("enter num1 : "))
num2 = float(input("enter num2 : "))
num3 = float(input("enter num3 : "))

avg = (num1 + num2 + num3) / 3

print("Average of numbers is", avg)
# Out:
# enter num1 :  4.5
# enter num2 :  3.5
# enter num3 :  2.0
# Average of numbers is 3.3333333333333335

# %% [raw]
# Program 7:
# write a program to take an integer input from the user  and print its type.
# input: 25
# output:the type of entered value is <class 'int'>

# %%
num = int(input("enter num: "))

print("the type of entered value is", type(num))
# Out:
# enter num:  25
# the type of entered value is <class 'int'>

# %% [raw]
# Program 8:
# write a program to take an string input from the user  and print its type.
# input: core2web
# output:the type of entered value is <class 'str'>

# %%
name = input("enter name: ")

print("the type of entered value is ",type(name))
# Out:
# enter name:  core2web
# the type of entered value is  <class 'str'>

# %% [raw]
# Program 9:
# write a program to take an float input from the user  and print its type.
# input: 7.89
# output:the type of entered value is <class 'float'>

# %%
num1 = float(input("enter num1: "))

print("the type of entered value is",type(num1))
# Out:
# enter num1:  7.89
# the type of entered value is <class 'float'>

# %% [raw]
# Program 10:
# write a program to take an two integer input from the user  and print their multiplication result.
#
# input: 4,6
# output:multiplication of 4 and 6 is 24

# %%
num1 =  int(input("enter num1 :"))
num2 =int(input("enter num2 :"))

multip = num1 * num2

print("multiplication of 4 and 6 is ",multip)
# Out:
# enter num1 : 4
# enter num2 : 6
# multiplication of 4 and 6 is  24
