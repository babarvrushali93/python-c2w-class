# %% [raw]
# question 1 :write a python program that:
# create two variables : x = 15 and y = 4
# performs all arithmetic operations :addition,subtrction,multiplication,division,modulus,floordivision,and exponentiation
# prints the results of each operation with appropiate labels.
#
# Expected output:
# addition:19
# subtrction:11
# multiplication:60
# division:3.75
# modulus:3
# floor division:3
# exponentiation:50625

# %%
x = 15
y = 4

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x // y)
print(x ** y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %% [raw]
# question2. write a python program that:
# create a variable num = 50
# applies compound assignment operators: +=,-=,*=,/=,%=,//=
# print(the value of num after each operation with appropriate labels
#
# Expexted output:
# initial value : 50
# After += 10 :60
# After -= 5 : 55
# After *= 2 110
# After /= 4 :27.5
# After %= 5 :2.5
# After //= 3:16

# %%
num = 50
print(num)

num += 10 
print(num)

num -= 5
print(num)

num *= 2
print(num)

num /= 4
print(num)

num %= 5
print(num)

num = 50
num //= 3
print(num)
# Out:
# 50
# 60
# 55
# 110
# 27.5
# 2.5
# 16

# %% [raw]
# question3 . write a python program that:
# create two varibale :a =25 and b = 30
# tests all relational operators: <,>,<=,>=,=<,==,!=.
# prints the reault of each comparison with appropriable labels
# Expected output:
# a = 25 , b = 30
# a<b:True
# a>b :False
# a<=b :True
# a>=b : False
# a==b : False
# a!=b : True

# %%
a = 25 
b = 30

print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %% [raw]
# question 4: write a python program that:
# create three varibale x = 10,y = 20,z = 30
# uses logical operators to test multiple conditions
# Test if x<y and y<z
# Test if x>y or y<z
# Test if not(x==y)
# prints all result eith appropriate lables
#
# Expecetd output:
# x = 10,y = 20,z =30
# True
# True
# True
# True

# %%
x = 10
y = 20
z =30

print(x < y and y<z)
print(x> y or y<z)
print(not(x==y))
# Out:
# True
# True
# True

# %% [raw]
# # identity
# question5. write a python program that:
# creates two integer variables:a = 100 and b = 100
# creates two list variables:list1 = [1][2][3] and list2 = [1][2][3]
# uses id() funtionnto print memory addresses
# uses id and is not operators to compare them
# print all result with explantions in comments.
#
# Expected output:
# Integer variables:
# a = 100 ,b =100
# id(a) = 14073489761852# (my vary)
# id(b) = 14073489761852# (my vary)
# a is b =  True
# a is not b =False
#
# List variables:
# list1 = [1][2][3] ,list2 = [1][2][3]
# id(list1) = 14073489761852# (my vary)
# id(list2) = 14073489761852# (my vary)
# list1 is list2 = False
# list1 == list2 =True
# list1 is not list2= True

# %%
# integer variables:
a = 100
b = 100

print(id(a))
print(id(b))

print(a is b)
print(a is not b)

# list variables
list1 = [1],[2],[3]
list2 = [1],[2],[3]

print(id(list1))
print(id(list2))

print(list1 is list2) 
print(list1 == list2)
print(list1 is not list2)
# Out:
# 140723048298008
# 140723048298008
# True
# False
# 1810425313728
# 1810425311872
# False
# True
# True

# %% [raw]
# # memoberyship operatros
# question 6: write a python program that:
# creates a list : colors = ["red","blue","green","yellow"]
# uses in operators to check if "blue" exists in the list.
# uses in operators to check if "purple" exists in the list.
# uses not in operators to check if "pink" is not in the list.
# uses not in operators to check if "red" is not in the list.
#
# Expected output:
# colors = ["red","blue","green","yellow"]
#
# "blue" in colors:True
# "purple" in colors : False
# "pink" not in colors:True
# "red" not in colors:False

# %%
colors = ["red","blue","green","yellow"]

print("blue" in colors)
print("purple" in colors)
print("pink" not in colors)
print("red" not in colors)
# Out:
# True
# False
# True
# False

# %% [raw]
# question 7: write a python program that:
# creates two variables x = 12 and y = 10
# performs bitwise operations: &(AND),|(OR),^(XOR),~(NOT),<<(left shift),>>(right shift)
# prints the results of each operation with appropriate labels.
#
# Expected output:
# x = 12      #(binary :1100)
# y = 10      #(binary: 1010)
# (x & y) :8
# (x | y):14
# x ^ y) :6
# (~x):-13
# (x << 2):48
# (x >> 2):3

# %%
# bitwise operation:

x = 12      #(binary :1100)
y = 10      #(binary: 1010)

print(x & y)
print(x | y)
print(x ^ y)
print(~x)
print(x << 2)
print(x >> 2)
# Out:
# 8
# 14
# 6
# -13
# 48
# 3

# %%
question 8: write a python program that:
creates variables of different data types: intval = 10,floatval= 5.5,stringval="Python"
perform opertions between compatiblle type and stores reults.
prints the data types of each result using type() function
print all result with labels.

expected output:
original values:
intval = 10 Type :<class 'int'>
floatval= 5.5 Type :<class 'flaot'>
stringval="Python" Type<class ' str'>


intval + floatval = 15.5 Type<class 'float'>
intval * floatval = 55.0 Type<class 'float'>
floatval / intval  = 0.55 Type<class 'float'>
stringval * 2 =pythonpython Type <class ' str'>

# %%
intval = 10
floatval= 5.5
stringval="Python"

print(type(intval))
print(type(floatval))
print(type(stringval))

print(intval + floatval)
print(intval * floatval)
print(floatval / intval) 
print(stringval * 2)

print(type(intval + floatval))
print(type(intval * floatval))
print(type(floatval / intval))
print(type(stringval * 2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 15.5
# 55.0
# 0.55
# PythonPython
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %% [raw]
# question 9: write a python program that:
# create two string varibales :first = "Hello" and second = "World"
# concatenates item using the + operator
# Repeats a string multiple times using the *operator
# prints the result each operation
#
# Expected output:
# first =Hello
# second = World
#
# concatenation(first + ''+second):Hello World
# Repatition(first * 3):HelloHelloHello
# Repatition(second * 2) :WorldWorld
# combination((first + '')*2+second):Hello Hello World

# %%
first = "Hello"
second = "World"

# concatenation
print(first+''+second)

#Repatition
print(first*3) 

#Repatition
print(second*2)

#combination
print((first + ' ')*2+second)
# Out:
# HelloWorld
# HelloHelloHello
# WorldWorld
# Hello Hello World

# %% [raw]
# question 10: write a python program that:
# creates variables:a =10,b=5,c =3
# calcultes the resultof :a+b*c
# calcultes the resultof :(a+b)*c
# calcultes the resultof :a**b//c
# calcultes the resultof :a<b and b>c or a==10
# prints all result.
#
# Expected output:
# a = 10,b=5,c = 3
# a+b*c = 10+5*3 =25
# (a+b)*c = (10 + 5)*3 = 45
# a**b//c=10**5//3=33333
#
# a<b and b>C or a==10
# = 10<5 and 5>3 or 10==10
# =False and True or True
# =False or True
# =True

# %%
a = 10
b = 5
c = 3

print(a+b*c)

print((a+b)*c)

print(a**b//c)


print((a<b) and (b>c) or (a==10))
# Out:
# 25
# 45
# 33333
# True
