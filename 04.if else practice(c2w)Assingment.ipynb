# %%
# p1.py

int x =10
int y =20

print(a + b)

# Explanation:
''' when we run the program ,if gives a syntax error ,
python uses the RTDI(run time data indentification) technique to define a
datatype for a variable,which is delected by its value.'''
# Out:
#   Cell In[1], line 3
#     int x =10
#         ^
# SyntaxError: invalid syntax

# %%
# correct code
x = 10
y = 20

print(x + y)
# Out:
# 30

# %%
# p2.py
x = input("enter num:")

if (x>0):
    print(x)

# Explanation: 
'''In this code ,we get a TypeError
Taking input from the user in string format and comparing it with an integer in the
if condition, which is not suitable requires convertaing the user input to an integer.'''
# Out:
# enter num: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 # p2.py
#       2 x = input("enter num:")
# ----> 4 if (x>0):
#       5     print(x)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# correct code:
x = int(input("enter num: "))

if (x > 0 ):
    print(x)
# Out:
# enter num:  4
# 4

# %%
# p3.py

x = int(input())
if x > 0 :
    print(x)
    if (x >0):
        print(x)
        
# Explanction:
'''The behavior of this code is that check the condition in the outer if.if
that condition is true ,it prints the value of x then it checks the condition in the
inner if(again, the same condition) ,and it's true ,it prints the value of x again.

the inner if statement is redundant,but it doesn't affect the code's logic;it just prints
the value of 'x' twice if it's grater than 0 .this type of code is known as "nested if" .'''
# Out:
#  3
# 3
# 3

# %%
# P4.py

x = int(input())

if x > 0:
    print(x)
    else:
      print(x)

# Explanation:
'''we think it gives an indentation error beacuse  it gives a synax error,
else is in the scope of the if statement; it seems else without if in the outer if condition.
if can run without an else statement ,but else cannot run without an if statement.'''
# Out:
#   Cell In[4], line 7
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
# P5.py
x = int(input())

if x > 0:
    print(x)
else (x < 0):
   print(x)

# Explanation
'''The else statement should not have a condition in parentheses.like(x < 0).
the else statement is for only other conditions that were failed to be executed.'''
# Out:
#   Cell In[8], line 6
#     else (x < 0):
#          ^
# SyntaxError: expected ':'

# %%
# correct code

x = int(input())

if x > 0:
    print(x)
else :
   print(x)
# Out:
#  10
# 10

# %%
# P6.py

x = int(input())

if x > 0:
    print(x)
else:
   print(x)

# Explation:
'''the program takes an integer input and check if it's grater than 0.
* If True,it print x.
* Else , it also prints x.
so, it will always print the entered number- the  if-else is redundant.
'''

# %%
# P7.py  ( the  program takes an integer input from the user.)

x = int(input())

if x > 0:
    print(x)
if (x == 0):
    print(x)
if (x < 0 ):
    print(x)

# Explation:
'''the  program takes an integer input from the user.
* it checks three separate conditions(not if-elif-else):
1. if x > 0 ----- print positive number
2. if x == 0 ----- print 0
3. if x < 0 ------ print negative number

since all are independent if statements.
only the condition that is true will print x.'''
# Out:
#  10
# 10

# %%
# P8.py
x = int(input())
if (x > 0):
    print(x)
elif(x == 0):
    print(x)
else:
    print(x)

# Explantion:
''' the program check the value of x usng if-elif-else structure:
if x > 0 ----print positive number

1.Else if x == 0 ----prints 0 
2. Else (means x < 0)--- prints negative number

since all blocks have print(X), it will always print the entered number.
but only one condtion is checked at atime beacause of if-elif-else.'''
# Out:
#  15
# 15

# %%
# P9.py
x = int(input())

if (x > 0):
    print(x)
elif(x == 0):
    print(x)
else:
print(x)

# Explantion:
''' thos code will give an IndentationError in python
print(x)
under the else: block is not indented properly.
in python every block (like if,elif or else) must have its code indented with spaces or tabs'''
# Out:
#   Cell In[17], line 9
#     print(x)
#     ^
# IndentationError: expected an indented block after 'else' statement on line 8

# %%
# correct code

x = int(input())

if (x > 0):
    print(x)
elif(x == 0):
    print(x)
else:
  print(x)
# Out:
#  10
# 10

# %%
# P10.py

num10 = 10
num20 = 20

sumData = num1 + num2
sumData = num2 - num1

if num1 > num2:
    print(sumData)
else:
    print(sumData)

# Explantion:
'''  the program adds and two numbers.
if num1 is grater than num2 . if prints their sum.
otherwise it prints difference.
here,since 10 > 20, the output is 10.
'''
# Out:
# 10
# '  the program adds and two numbers.\nif num1 is grater than num2 . if prints their sum.\notherwise it prints difference.\nhere,since 10 > 20, the output is 10.\n'
