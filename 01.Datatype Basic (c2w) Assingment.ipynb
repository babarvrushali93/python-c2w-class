# %% [markdown]
# 1. write a python program to print "Core2web".

# %%
print("Core2web")
# Out:
# Core2web

# %% [markdown]
# 2.write a python program to assign a value to an integer variable and print it.

# %%
a = 10
print(10)
# Out:
# 10

# %% [markdown]
# 3. write a python program to assign a float varibale and print its types.

# %%
a = 2.5
print(a)
print(type(a))
# Out:
# 2.5
# <class 'float'>

# %% [markdown]
# 4. write a python program to assign a value to a complex variable and print it.

# %%
a = 2 + 3j
print(a)
# Out:
# (2+3j)

# %% [markdown]
# 5. write a program to store your name in a variable and print it.

# %%
x = "vrushali"
print(x)
# Out:
# vrushali

# %% [markdown]
# 6.write a program to assign a boolen value to a variable and display it.

# %%
x = True
y = False
print(x)
print(y)
# Out:
# True
# False

# %% [markdown]
# 7. write a python program to assign the number 25 to a variable and print its type using the type() function.

# %%
num =25
print(num)
print(type(num))
# Out:
# 25
# <class 'int'>

# %% [markdown]
# 8. write a python program to assign the number 31.5 to a variable and print its type using the type() function.

# %%
num = 31.5
print(num)
print(type(num))
# Out:
# 31.5
# <class 'float'>

# %% [markdown]
# 9. Assign two integers and one float to variables ,add them ,print the sum.

# %%
x = 10
y = 20
z = 5.5
sum = x+y+z
print(sum)
# Out:
# 35.5

# %% [markdown]
# 10. write a python program to create a list of 5 subjects and print each subject using Indexing.

# %%
data = [10,20,30,40,50]
print(data)

print(data[0])
print(data[1])
print(data[2])
print(data[3])
print(data[4])
# Out:
# [10, 20, 30, 40, 50]
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# 11. write a program to create a tuple.

# %%
tupledata = (10,20,30,40,50)
print(tupledata)
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# 12. write the program to create a list and print sum of all index values.

# %%
listdata = [1,2,3,4]
valsum = listdata[0] + listdata[1] + listdata[2] + listdata[3]
print(valsum)
# Out:
# 10

# %% [markdown]
# 13. write a python program to create a set of numbers and show that duplications are not allowed.

# %%
setdata = {10,20,10,30,40}
print(setdata)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# 14 . write a python program to create the list and perform list operations assign a "Core2web" to a 3 index.

# %%
data = [10,20,30,"c2w",40]
print(data)

data[3] = "Core2web"

print(data)
# Out:
# [10, 20, 30, 'c2w', 40]
# [10, 20, 30, 'Core2web', 40]

# %% [markdown]
# 15 . write a program to create a dictionary of student data (name,age,marks) and print each value of key.

# %%
dictdata = {'name' : "vrushali", 'age' : "25" , 'marks' : "80"}
print(dictdata['name'])
print(dictdata['age'])
print(dictdata['marks'])
# Out:
# vrushali
# 25
# 80

# %% [markdown]
# 16. write a program to assign a new value to a key in a dictionary.

# %%
dict = {18 : "Virat",45 : "Rohit",7 :"MSD"}
print(dict)
dict[7] = "Mahi"
print(dict)
# Out:
# {18: 'Virat', 45: 'Rohit', 7: 'MSD'}
# {18: 'Virat', 45: 'Rohit', 7: 'Mahi'}

# %% [markdown]
# 17. write a python program to check if a key exists in the dictionary {0:10,1:20,2:25,3:30,4:40}
# if the key exists,print its value.
# then , find the sum of the values associated with keys 2 and 3, and print the result.

# %%
key = {0:10,1:20,2:25,3:30,4:40}

print(key)
sum = key[2] + key[3]
print(sum)
# Out:
# {0: 10, 1: 20, 2: 25, 3: 30, 4: 40}
# 55

# %% [markdown]
# 18. write a python program to assign a value to a None variable and print it.

# %%
x = None
print(x)
# Out:
# None

# %% [markdown]
# 19. write a python program that displays three strings using all three types od string declarations.
# 1.one string using single quotes
# 2.one srting using double quotes
# 3.one multi-line using triple quotes

# %%
name1= "Kanha"
name2 = 'ashish'
name3 = """Madhu""" or '''kale'''

print(name1)
print(name2)
print(name3)
# Out:
# Kanha
# ashish
# Madhu

# %% [raw]
# 20.Assigns a value to each of the following data types.
# .Integer(int)
# .Float(float)
# .Complex(complex)
# .String(string)
# .List(list)
# .Tuple(tuple)
# .Dictionary(dict)
# .Set(set)
# .Boolean(bool)
# . None

# %%
intdata = 10
floatdata = 10.5
compdata = 2+3j
string = "kanha"     # """core2web""" or '''c2w''' or 'mahi'
list1 = [10,20,30,40]
tuple1 = (20,30,40,"c2w",50)
dict1 = {45:"Rohit",7:"MSD",18:"Virat"}
set1 = {10,20,60,70,"mahi"}
bool1 = True
z = None

print(type(intdata))
print(type(floatdata))
print(type(compdata))
print(type(string))
print(type(list1))
print(type(tuple1))
print(type(dict1))
print(type(set1))
print(type(bool1))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>
# <class 'bool'>
# <class 'NoneType'>
